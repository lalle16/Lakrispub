# %% [markdown]
# # Sentiment analysis of US tech media
# This notebook performs sentiment analysis of US tech media.
# News are gathered via NewsAPI.
# Sentiment analysis is calculated with TextBlob.
# Named Entity Recognition is done with spaCy.
# The results are visualized in a separate Tableau visualization.

# %%
import pandas as pd
from configparser import ConfigParser
import sqlalchemy
from sqlalchemy import create_engine
import re
from textblob import TextBlob
import spacy
#!python -m spacy download en_core_web_sm

# %% [markdown]
# ## Retrieve news from database

# %%
# Get keys from config file
parser = ConfigParser()
_ = parser.read('keys.cfg')

# %%
# Connect to database
engine = create_engine(parser.get('news','conn_string'))

# %%
# Read from the database and turn into dataframe
news_df = pd.read_sql_query('select * from "news"',con=engine)
sources_df = pd.read_sql_query('select * from "sources"',con=engine)

# %%
news_df.head()
# Out:
#                author                                              title  \
# 0       Stephen Clark  NASA wants Starliner to make a quick getaway f...
# 1           Beth Mole  Person in Missouri caught H5 bird flu without ...
# 2         Kevin Purdy  Balatro arrives on phones Sept. 26, so plan yo...
# 3  Jennifer Ouellette  Jack Black stars as expert crafter Steve in A ...
# 4  Jennifer Ouellette  Cats play fetch more often than previously bel...
#
#                                          description  \
# 0  Starliner is set to land at White Sands Space ...
# 1  The person recovered, and Missouri officials s...
# 2  It has already sold 2 million copies. Now the ...
# 3  "Anything you can dream about here, you can ma...
# 4  About 4 in 10 cats and nearly 8 in 10 dogs lik...
#
#                                                  url  \
# 0  https://arstechnica.com/space/2024/09/boeings-...
# 1  https://arstechnica.com/science/2024/09/missou...
# 2  https://arstechnica.com/gaming/2024/09/balatro...
# 3  https://arstechnica.com/culture/2024/09/magica...
# 4  https://arstechnica.com/science/2024/09/cats-p...
#
#                                           urlToImage           publishedAt  \
# 0  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-06T21:50:35Z
# 1  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-06T23:02:37Z
# 2  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-05T17:38:52Z
# 3  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-04T19:47:36Z
# 4  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-04T18:00:00Z
#
#                                              content     source.id  \
# 0  Enlarge/ Boeing's Starliner spacecraft is set ...  ars-technica
# 1  Enlarge/ The influenza virus from an image pro...  ars-technica
# 2  Enlarge/ The energy captured by Balatro's mobi...  ars-technica
# 3  12\r\nJason Momoa and Jack Black star in A Min...  ars-technica
# 4  9\r\nAlthough more common in dogs, 4 in 10 pet...  ars-technica
#
#     source.name
# 0  Ars Technica
# 1  Ars Technica
# 2  Ars Technica
# 3  Ars Technica
# 4  Ars Technica

# %% [markdown]
# ## Preprocess text

# %%
def cleanText(sentence):
    sentence = str(sentence)
    
    # Special characters
    sentence = re.sub(r"[^a-zA-Z0–9\s]", "", sentence)
    # tags
    sentence = re.sub(r"<.*?>", " ", sentence)
    # links
    sentence = re.sub(r"http\S+", " ", sentence)
    # numbers
    sentence = re.sub("[0-9]+", " ", sentence)
    # newlines
    sentence = re.sub("\n", " ", sentence)
    # CR
    sentence = re.sub(r"^[\r\n]+|\.|[\r\n]+$"," ",sentence)

    return sentence

# %%
news_df['title_clean'] = news_df['title'].apply(cleanText)
news_df['description_clean'] = news_df['description'].apply(cleanText)
news_df['content_clean'] = news_df['content'].apply(cleanText)

# %% [markdown]
# ## Calculate sentiment scores

# %%
# Get Subjectivity
def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity

# Get Polarity
def getPolarity(text):
   return TextBlob(text).sentiment.polarity

# %%
def analyze_text_column(df, column):
    df[f'{column}_subjectivity'] = df[column].apply(getSubjectivity)
    df[f'{column}_polarity'] = df[column].apply(getPolarity)
    df[f'{column}_polarity_label'] = df[f'{column}_polarity'].apply(lambda x: 'negative' if x < 0 else 'neutral' if x == 0 else 'positive')

# %%
analyze_text_column(news_df, 'title_clean')
analyze_text_column(news_df, 'content_clean')
analyze_text_column(news_df, 'description_clean')

# %%
news_df.head()
# Out:
#                author                                              title  \
# 0       Stephen Clark  NASA wants Starliner to make a quick getaway f...
# 1           Beth Mole  Person in Missouri caught H5 bird flu without ...
# 2         Kevin Purdy  Balatro arrives on phones Sept. 26, so plan yo...
# 3  Jennifer Ouellette  Jack Black stars as expert crafter Steve in A ...
# 4  Jennifer Ouellette  Cats play fetch more often than previously bel...
#
#                                          description  \
# 0  Starliner is set to land at White Sands Space ...
# 1  The person recovered, and Missouri officials s...
# 2  It has already sold 2 million copies. Now the ...
# 3  "Anything you can dream about here, you can ma...
# 4  About 4 in 10 cats and nearly 8 in 10 dogs lik...
#
#                                                  url  \
# 0  https://arstechnica.com/space/2024/09/boeings-...
# 1  https://arstechnica.com/science/2024/09/missou...
# 2  https://arstechnica.com/gaming/2024/09/balatro...
# 3  https://arstechnica.com/culture/2024/09/magica...
# 4  https://arstechnica.com/science/2024/09/cats-p...
#
#                                           urlToImage           publishedAt  \
# 0  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-06T21:50:35Z
# 1  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-06T23:02:37Z
# 2  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-05T17:38:52Z
# 3  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-04T19:47:36Z
# 4  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-04T18:00:00Z
#
#                                              content     source.id  \
# 0  Enlarge/ Boeing's Starliner spacecraft is set ...  ars-technica
# 1  Enlarge/ The influenza virus from an image pro...  ars-technica
# 2  Enlarge/ The energy captured by Balatro's mobi...  ars-technica
# 3  12\r\nJason Momoa and Jack Black star in A Min...  ars-technica
# 4  9\r\nAlthough more common in dogs, 4 in 10 pet...  ars-technica
#
#     source.name                                        title_clean  ...  \
# 0  Ars Technica  NASA wants Starliner to make a quick getaway f...  ...
# 1  Ars Technica  Person in Missouri caught H bird flu without a...  ...
# 2  Ars Technica  Balatro arrives on phones Sept  so plan your s...  ...
# 3  Ars Technica  Jack Black stars as expert crafter Steve in A ...  ...
# 4  Ars Technica  Cats play fetch more often than previously bel...  ...
#
#                                        content_clean title_clean_subjectivity  \
# 0  Enlarge Boeings Starliner spacecraft is set to...                 0.300000
# 1  Enlarge The influenza virus from an image prod...                 0.000000
# 2  Enlarge The energy captured by Balatros mobile...                 0.857143
# 3    Jason Momoa and Jack Black star in A Minecra...                 0.433333
# 4   \r Although more common in dogs  in   pet cat...                 0.244444
#
#    title_clean_polarity  title_clean_polarity_label  \
# 0              0.266667                    positive
# 1              0.000000                     neutral
# 2             -0.714286                    negative
# 3             -0.166667                    negative
# 4              0.055556                    positive
#
#   content_clean_subjectivity  content_clean_polarity  \
# 0                   0.000000                0.000000
# 1                   0.000000                0.000000
# 2                   1.000000               -1.000000
# 3                   0.572222                0.363889
# 4                   0.500000                0.100000
#
#    content_clean_polarity_label description_clean_subjectivity  \
# 0                       neutral                       0.251515
# 1                       neutral                       0.183333
# 2                      negative                       0.150000
# 3                      positive                       0.000000
# 4                      positive                       0.700000
#
#    description_clean_polarity  description_clean_polarity_label
# 0                    0.045455                          positive
# 1                    0.000000                           neutral
# 2                    0.150000                          positive
# 3                    0.000000                           neutral
# 4                    0.050000                          positive
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Perform Named Entity Recognition

# %%
# Load the spaCy model
nlp = spacy.load("en_core_web_sm")

def extract_entities(df, column):
    # Apply NER to each text sample in the column
    entities = df[column].apply(lambda text: [(ent.text, ent.label_) for ent in nlp(text).ents])

    # Create new columns for entities
    df[f'{column}_entities'] = entities

    return df

# %%
news_df = extract_entities(news_df, 'title_clean')

# %% [markdown]
# ## Calculate entity sentiment

# %%
def calculate_entity_polarity(df, key_column, polarity_columns):
    entity_polarity_df = pd.DataFrame({
        'Key': df[key_column],
        'Entity': df[key_column].apply(lambda x: [ent[0] for ent in x]),
        'Entity_Type': df[key_column].apply(lambda x: [ent[1] for ent in x]),
    })

    for polarity_column in polarity_columns:
        entity_polarity_df[polarity_column] = df[polarity_column]

    entity_polarity_df = entity_polarity_df.explode('Entity')
    entity_polarity_df = entity_polarity_df.explode('Entity_Type')

    entity_polarity_df_sums = []
    for polarity_column in polarity_columns:
        entity_polarity_df_sum = entity_polarity_df.groupby(['Entity', 'Entity_Type'])[polarity_column].agg(['mean', 'var', 'count']).reset_index()
        entity_polarity_df_sum.columns = [f'{col}_{polarity_column}' if col != 'Entity' and col != 'Entity_Type' else col for col in entity_polarity_df_sum.columns]
        entity_polarity_df_sums.append(entity_polarity_df_sum)

    merged_df = pd.merge(*entity_polarity_df_sums, on=['Entity', 'Entity_Type'])

    merged_df = pd.merge(merged_df, entity_polarity_df, on=['Entity', 'Entity_Type'], suffixes=('_agg', ''))

    merged_df.drop_duplicates(subset=['Entity', 'Entity_Type'], inplace=True)

    return merged_df

# %%
entity_df = calculate_entity_polarity(news_df, 'title_clean_entities', ['title_clean_polarity', 'description_clean_polarity'])

# %% [markdown]
# ## Output

# %%
entity_df.head()
# Out:
#                    Entity  Entity_Type  mean_title_clean_polarity  \
# 0  A Small Light and Togo          ORG                  -0.004167
# 2  A Small Light and Togo  WORK_OF_ART                  -0.004167
# 3                     AFP         NORP                   0.000000
# 4                     AFP          ORG                   0.000000
# 6                     AGI          ORG                   0.000000
#
#    var_title_clean_polarity  count_title_clean_polarity  \
# 0                       0.0                           2
# 2                       NaN                           1
# 3                       NaN                           1
# 4                       0.0                           2
# 6                       0.0                           2
#
#    mean_description_clean_polarity  var_description_clean_polarity  \
# 0                             0.50                             0.0
# 2                             0.50                             NaN
# 3                             0.00                             NaN
# 4                             0.00                             0.0
# 6                            -0.29                             0.0
#
#    count_description_clean_polarity  \
# 0                                 2
# 2                                 1
# 3                                 1
# 4                                 2
# 6                                 2
#
#                                                  Key  title_clean_polarity  \
# 0  [(Disney, ORG), (Disney, ORG), (A Small Light ...             -0.004167
# 2  [(Disney, ORG), (Disney, ORG), (A Small Light ...             -0.004167
# 3    [(AFP, ORG), (French, NORP), (TechCrunch, ORG)]              0.000000
# 4    [(AFP, ORG), (French, NORP), (TechCrunch, ORG)]              0.000000
# 6     [(AI, ORG), (AGI, ORG), (TechCrunch, PRODUCT)]              0.000000
#
#    description_clean_polarity
# 0                        0.50
# 2                        0.50
# 3                        0.00
# 4                        0.00
# 6                       -0.29

# %%
news_df.head()
# Out:
#                author                                              title  \
# 0       Stephen Clark  NASA wants Starliner to make a quick getaway f...
# 1           Beth Mole  Person in Missouri caught H5 bird flu without ...
# 2         Kevin Purdy  Balatro arrives on phones Sept. 26, so plan yo...
# 3  Jennifer Ouellette  Jack Black stars as expert crafter Steve in A ...
# 4  Jennifer Ouellette  Cats play fetch more often than previously bel...
#
#                                          description  \
# 0  Starliner is set to land at White Sands Space ...
# 1  The person recovered, and Missouri officials s...
# 2  It has already sold 2 million copies. Now the ...
# 3  "Anything you can dream about here, you can ma...
# 4  About 4 in 10 cats and nearly 8 in 10 dogs lik...
#
#                                                  url  \
# 0  https://arstechnica.com/space/2024/09/boeings-...
# 1  https://arstechnica.com/science/2024/09/missou...
# 2  https://arstechnica.com/gaming/2024/09/balatro...
# 3  https://arstechnica.com/culture/2024/09/magica...
# 4  https://arstechnica.com/science/2024/09/cats-p...
#
#                                           urlToImage           publishedAt  \
# 0  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-06T21:50:35Z
# 1  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-06T23:02:37Z
# 2  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-05T17:38:52Z
# 3  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-04T19:47:36Z
# 4  https://cdn.arstechnica.net/wp-content/uploads...  2024-09-04T18:00:00Z
#
#                                              content     source.id  \
# 0  Enlarge/ Boeing's Starliner spacecraft is set ...  ars-technica
# 1  Enlarge/ The influenza virus from an image pro...  ars-technica
# 2  Enlarge/ The energy captured by Balatro's mobi...  ars-technica
# 3  12\r\nJason Momoa and Jack Black star in A Min...  ars-technica
# 4  9\r\nAlthough more common in dogs, 4 in 10 pet...  ars-technica
#
#     source.name                                        title_clean  ...  \
# 0  Ars Technica  NASA wants Starliner to make a quick getaway f...  ...
# 1  Ars Technica  Person in Missouri caught H bird flu without a...  ...
# 2  Ars Technica  Balatro arrives on phones Sept  so plan your s...  ...
# 3  Ars Technica  Jack Black stars as expert crafter Steve in A ...  ...
# 4  Ars Technica  Cats play fetch more often than previously bel...  ...
#
#   title_clean_subjectivity title_clean_polarity  title_clean_polarity_label  \
# 0                 0.300000             0.266667                    positive
# 1                 0.000000             0.000000                     neutral
# 2                 0.857143            -0.714286                    negative
# 3                 0.433333            -0.166667                    negative
# 4                 0.244444             0.055556                    positive
#
#    content_clean_subjectivity content_clean_polarity  \
# 0                    0.000000               0.000000
# 1                    0.000000               0.000000
# 2                    1.000000              -1.000000
# 3                    0.572222               0.363889
# 4                    0.500000               0.100000
#
#    content_clean_polarity_label  description_clean_subjectivity  \
# 0                       neutral                        0.251515
# 1                       neutral                        0.183333
# 2                      negative                        0.150000
# 3                      positive                        0.000000
# 4                      positive                        0.700000
#
#   description_clean_polarity  description_clean_polarity_label  \
# 0                   0.045455                          positive
# 1                   0.000000                           neutral
# 2                   0.150000                          positive
# 3                   0.000000                           neutral
# 4                   0.050000                          positive
#
#                                 title_clean_entities
# 0                 [(NASA, ORG), (Starliner, PERSON)]
# 1                                  [(Missouri, GPE)]
# 2                                                 []
# 3  [(Jack Black, PERSON), (Steve, PERSON), (Minec...
# 4                                                 []
#
# [5 rows x 22 columns]
